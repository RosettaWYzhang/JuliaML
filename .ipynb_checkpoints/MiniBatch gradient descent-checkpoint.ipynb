# %%
# use mini batch to perform gradient descent

using Flux.Tracker
using Plots

# %%
N=1000 # number of training points
D=3 # dimension of each x vector
batchSize = 50
batchNum = convert(Int, N/batchSize)
iterations = 20
η = 1.5
k = 0.15
λ = 0.9 #for momentum
Vdw = 0
Vdb = 0
# Out:
# 0

# %%
# fake dataset
x=randn(D,N)
w_david=randn(1,D)
b_david=randn()
# assume we try to predict a scalar output
y=zeros(1,N)
for n=1:N
    y[n] = sum(w_david * x[:,n] .+ b_david)
end

# %%
#visualise the dataset
plotly() # Choose the Plotly.jl backend for web interactivity
plot(x,y,seriestype=:scatter,title="dataset")
# Out:
# <script src="/Users/wanyuezhang/.julia/v0.6/Plots/src/backends/../../deps/plotly-latest.min.js"></script>    <div id="f4943f63-4401-4e6a-bde2-c48abe10d2e0" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('f4943f63-4401-4e6a-bde2-c48abe10d2e0');
#     Plotly.plot(PLOT, [{"showlegend":true,"mode":"markers","xaxis":"x","colorbar":{"title":""},"marker":{"symbol":"circle","color":"rgba(0, 154, 250, 1.000)","line":{"color":"rgba(0, 0, 0, 1.000)","width":1},"size":8},"y":[1397.031510546241],"type":"scatter","name":"y1","yaxis":"y","x":[-1.3046419889784324,1.1304673603695525,-0.19784413355991273]},{"showlegend":true,"mode":"markers","xaxis":"x","colorbar":{"title":""},"marker":{"symbol":"circle","color":"rgba(227, 111, 71, 1.000)","line":{"color":"rgba(0, 0, 0, 1.000)","width":1},"size":8},"y":[1397.031510546241],"type":"scatter","name":"y2","yaxis":"y","x":[1.3992568335469437,-0.8462854378265392,-0.29324073230521314]},{"showlegend":true,"mode":"markers","xaxis":"x","colorbar":{"title":""},"marker":{"symbol":"circle","color":"rgba(62, 164, 78, 1.000)","line":{"color":"rgba(0, 0, 0, 1.000)","width":1},"size":8},"y":[1397.031510546241],"type":"scatter","name":"y3","yaxis":"y","x":[0.22556294830025478,0.22747258765046052,-2.0058966436313215]},{"showlegend":true,"mode":"markers","xaxis":"x","colorbar":{"title":""},"marker":{"symbol":"circle","color":"rgba(195, 113, 210, 1.000)","line":{"color":"rgba(0, 0, 0, 1.000)","width":1},"size":8},"y":[1397.031510546241],"type":"scatter","name":"y4","yaxis":"y","x":[1.0024508204746918,-0.23679454111268813,-0.28749107723210565]},{"showlegend":true,"mode":"markers","xaxis":"x","colorbar":{"title":""},"marker":{"symbol":"circle","color":"rgba(172, 142, 24, 1.000)","line":{"color":"rgba(0, 0, 0, 1.000)","width":1},"size":8},"y":[1397.031510546241],"type":"scatter","name":"y5","yaxis":"y","x":[0.6997522839260734,-0.6906191140969022,0.8762130680153575]},{"showlegend":true,"mode":"markers","xaxis":"x","colorbar":{"title":""},"marker":{"symbol":"circle","color":"rgba(0, 170, 174, 1.000)","line":{"color":"rgba(0, 0, 0, 1.000)","width":1},"size":8},"y":[1397.031510546241],"type":"scatter","name":"y6","yaxis":"y","x":[0.19420134642042455,0.6427495081380341,0.08035886788446119]},{"showlegend":true,"mode":"markers","xaxis":"x","colorbar":{"title":""},"marker":{"symbol":"circle","color":"rgba(237, 94, 147, 1.000)","line":{"color":"rgba(0, 0, 0, 1.000)","width":1},"size":8},"y":[1397.031510546241],"type":"scatter","name":"y7","yaxis":"y","x":[-2.006566056397106,-0.044836270637547096,0.2387250709717373]},{"showlegend":true,"mode":"markers","xaxis":"x","colorbar":{"title":""},"marker":{"symbol":"circle","color":"rgba(198, 130, 37, 1.000)","line":{"color":"rgba(0, 0, 0, 1.000)","width":1},"size":8},"y":[1397.031510546241],"type":"scatter","name":"y8","yaxis":"y","x":[1.5516338954146203,-0.8986089530980744,-0.9653019672428044]},{"showlegend":true,"mode":"markers","xaxis":"x","colorbar":{"title":""},"marker":{"symbol":"circle","color":"rgba(0, 169, 141, 1.000)","line":{"color":"rgba(0, 0, 0, 1.000)","width":1},"size":8},"y":[1397.031510546241],"type":"scatter","name":"y9","yaxis":"y","x":[-0.4677869702574047,-1.194124095680684,0.1413230960580718]},{"showlegend":true,"mode":"markers","xaxis":"x","colorbar":{"title":""},"marker":{"symbol":"circle","color":"rgba(142, 151, 30, 1.000)","line":{"color":"rgba(0, 0, 0, 1.000)","width":1},"size":8},"y":[1397.031510546241],"type":"scatter","name":"y10","yaxis":"y","x":[0.3314652581819481,0.6453727330363256,-0.6701920363215434]},{"showlegend":true,"mode":"markers","xaxis":"x","colorbar":{"title":""},"marker":{"symbol":"circle","color":"rgba(0, 169, 204, 1.000)","line":{"color":"rgba(0, 0, 0, 1.000)","width":1},"size":8},"y":[1397.031510546241],"type":"scatter","name":"y11","yaxis":"y","x":[1.0885140610193909,-0.24215759512898732,-1.0994802726642383]},{"showlegend":true,"mode":"markers","xaxis":"x","colorbar":{"title":""},"marker":{"symbol":"circle","color":"rgba(155, 127, 233, 1.000)","line":{"color":"rgba(0, 0, 0, 1.000)","width":1},"size":8},"y":[1397.031510546241],"type":"scatter","name":"y12","yaxis":"y","x":[3.438684565292236,-0.8544216249980556,-1.2706298321518499]},{"showlegend":true,"mode":"markers","xaxis":"x","c ...

# %%
# David gives Wanyue only x,y and Wanyue has to try to find w_david and b_david
# randomly initiate weight and bias
w = param(randn(1,D))
b = param(randn())
# Out:
# Tracked 0-dimensional Array{Float64,0}:
# -1.13221

# %%
predict(x) = w*x .+ b
meansquareloss(yhat, y_batch) = sum((yhat - y_batch').^2)/N
# Out:
# meansquareloss (generic function with 1 method)

# %%
function E(bn)
  x_batch = x[:,(bn-1)*batchSize+1: bn*batchSize]
  y_batch = y[(bn-1)*batchSize+1: bn*batchSize]
  meansquareloss(predict(x_batch),y_batch)
end
# Out:
# E (generic function with 1 method)

# %%
# Minibatch gradient descent
function update!(w, b, i, Vdw = 0, Vdb = 0, eta = η)
    eta = eta/(1+i*k) # learning rate annealing
    Vdw = w.grad * (1-λ) + Vdw * λ
    Vdb = b.grad * (1-λ) + Vdb * λ
    w.data .-= Vdw .* eta
    b.data .-= Vdb .* eta
    w.grad .= 0
    b.grad .= 0;
    return Vdw, Vdb
end
# Out:
# update! (generic function with 4 methods)

# %%
for i = 1:iterations
  for bn = 1:batchNum
    back!(E(bn))
    Vdw, Vdb = update!(w,b,i,Vdw,Vdb)
    @show E(bn)
  end
end
# Out:
# E(bn) = param(95200.2)
# E(bn) = param(90449.2)
# E(bn) = param(84062.4)
# E(bn) = param(76393.4)
# E(bn) = param(67830.8)
# E(bn) = param(58848.3)
# E(bn) = param(50010.1)
# E(bn) = param(41197.8)
# E(bn) = param(33910.0)
# E(bn) = param(26619.4)
# E(bn) = param(19586.6)
# E(bn) = param(14485.4)
# E(bn) = param(10159.3)
# E(bn) = param(6965.01)
# E(bn) = param(4003.13)
# E(bn) = param(2213.28)
# E(bn) = param(1209.7)
# E(bn) = param(245.926)
# E(bn) = param(114.292)
# E(bn) = param(349.002)
# E(bn) = param(679.466)
# E(bn) = param(1113.02)
# E(bn) = param(1627.09)
# E(bn) = param(2086.2)
# E(bn) = param(2660.84)
# E(bn) = param(2985.05)
# E(bn) = param(3265.34)
# E(bn) = param(3489.71)
# E(bn) = param(3556.69)
# E(bn) = param(3579.75)
# E(bn) = param(3540.07)
# E(bn) = param(3418.5)
# E(bn) = param(3197.3)
# E(bn) = param(3038.36)
# E(bn) = param(2723.0)
# E(bn) = param(2469.16)
# E(bn) = param(2229.6)
# E(bn) = param(1757.61)
# E(bn) = param(1616.23)
# E(bn) = param(1215.42)
# E(bn) = param(1022.11)
# E(bn) = param(823.785)
# E(bn) = param(649.902)
# E(bn) = param(502.968)
# E(bn) = param(336.187)
# E(bn) = param(259.044)
# E(bn) = param(173.402)
# E(bn) = param(110.558)
# E(bn) = param(78.3129)
# E(bn) = param(44.0129)
# E(bn) = param(14.7721)
# E(bn) = param(9.35897)
# E(bn) = param(8.65074)
# E(bn) = param(8.12017)
# E(bn) = param(18.2173)
# E(bn) = param(27.3331)
# E(bn) = param(35.2078)
# E(bn) = param(52.2406)
# E(bn) = param(57.3308)
# E(bn) = param(71.3859)
# E(bn) = param(76.7801)
# E(bn) = param(79.864)
# E(bn) = param(81.7416)
# E(bn) = param(82.6178)
# E(bn) = param(86.3102)
# E(bn) = param(81.4346)
# E(bn) = param(78.4423)
# E(bn) = param(73.3588)
# E(bn) = param(69.0795)
# E(bn) = param(63.7056)
# E(bn) = param(56.0899)
# E(bn) = param(50.4617)
# E(bn) = param(45.4492)
# E(bn) = param(40.5729)
# E(bn) = param(33.3447)
# E(bn) = param(28.2584)
# E(bn) = param(26.1129)
# E(bn) = param(18.0794)
# E(bn) = param(16.3807)
# E(bn) = param(11.2628)
# E(bn) = param(9.33455)
# E(bn) = param(7.3404)
# E(bn) = param(5.55625)
# E(bn) = param(4.02442)
# E(bn) = param(2.1702)
# E(bn) = param(1.84044)
# E(bn) = param(1.01308)
# E(bn) = param(0.656902)
# E(bn) = param(0.556404)
# E(bn) = param(0.311602)
# E(bn) = param(0.200893)
# E(bn) = param(0.328692)
# E(bn) = param(0.353753)
# E(bn) = param(0.409993)
# E(bn) = param(0.607611)
# E(bn) = param(0.74075)
# E(bn) = param(0.790615)
# E(bn) = param(0.979953)
# E(bn) = param(1.03419)
# E(bn) = param(1.16264)
# E(bn) = param(1.1928)
# E(bn) = param(1.19348)
# E(bn) = param(1.17294)
# E(bn) = param(1.16113)
# E(bn) = param(1.20088)
# E(bn) = param(1.12059)
# E(bn) = param(1.0744)
# E(bn) = param(0.99415)
# E(bn) = param(0.941837)
# E(bn) = param(0.8735)
# E(bn) = param(0.758727)
# E(bn) = param(0.688755)
# E(bn) = param(0.64215)
# E(bn) = param(0.581443)
# E(bn) = param(0.477569)
# E(bn) = param(0.410403)
# E(bn) = param(0.407606)
# E(bn) = param(0.283029)
# E(bn) = param(0.26583)
# E(bn) = param(0.194162)
# E(bn) = param(0.17037)
# E(bn) = param(0.144633)
# E(bn) = param(0.117024)
# E(bn) = param(0.091617)
# E(bn) = param(0.0536468)
# E(bn) = param(0.0529202)
# E(bn) = param(0.0340412)
# E(bn) = param(0.0268952)
# E(bn) = param(0.0255591)
# E(bn) = param(0.0177421)
# E(bn) = param(0.00804993)
# E(bn) = param(0.00745759)
# E(bn) = param(0.0071502)
# E(bn) = param(0.00362936)
# E(bn) = param(0.0044592)
# E(bn) = param(0.00378173)
# E(bn) = param(0.00437556)
# E(bn) = param(0.0059284)
# E(bn) = param(0.00567858)
# E(bn) = param(0.00758324)
# E(bn) = param(0.00835305)
# E(bn) = param(0.0084799)
# E(bn) = param(0.00846681)
# E(bn) = param(0.00873039)
# E(bn) = param(0.0110958)
# E(bn) = param(0.00989812)
# E(bn) = param(0.0101111)
# E(bn) = param(0.0096467)
# E(bn) = param(0.00922973)
# E(bn) = param(0.00894859)
# E(bn) = param(0.00862139)
# E(bn) = param(0.00826525)
# E(bn) = param(0.00790728)
# E(bn) = param(0.00780284)
# E(bn) = param(0.00668419)
# E(bn) = param(0.00622149)
# E(bn) = param(0.00644925)
# E(bn) = param(0.0047956)
# E(bn) = param(0.00482587)
# E(bn) = param(0.00393036)
# E(bn) = param(0.00360771)
# E(bn) = param(0.00332085)
# E(bn) = param(0.00288803)
# E(bn) = param(0.00250169)
# E(bn) = param(0.00172272)
# E(bn) = param(0.00182034)
# E(bn) = param(0.00142849)
# E(bn) = param(0.00125289)
# E(bn) = param(0.00123277)
# E(bn) = param(0.00103605)
# E(bn) = param(0.0006372)
# E(bn) = param(0.000540484)
# E(bn) = param(0.000554233)
# E(bn) = param(0.000377956)
# E(bn) = param(0.00028315)
# E(bn) = param(0.000173657)
# E(bn) = param(0.000218067)
# E(bn) = param(0.000127577)
# E(bn) = param(8.60013e-5)
# E(bn) = param(6.2086e-5)
# E(bn) = param(6.83775e-5)
# E(bn) = param(5.50893e-5)
# E(bn) = param(4.08889e-5)
# E(bn) = param(2.75098e-5)
# E(bn) = param(4.66282e-5)
# E(bn) = param(3.07709e-5)
# E(bn) = param(2.52893e-5)
# E(bn) = param(2.70029e-5)
# E(bn) = param(2.58359e-5)
# E(bn) = param(2.36628e-5)
# E(bn) = param(3.42233e-5)
# E(bn) = param(3.91548e-5)
# E(bn) = param(3.51858e-5)
# E(bn) = param(4.12611e-5)
# E(bn) = param(3.99984e-5)
# E(bn) = param(4.31195e-5)
# E(bn) = param(4.35717e-5)
# E(bn) = param(3.74228e-5)
# E(bn) = param(4.10501e-5)
# E(bn) = param(3.87124e-5)
# E(bn) = param(3.69275e-5)
# E(bn) = param(3.61723e-5)
# E(bn) = param(3.32321e-5)
# E(bn) = param(3.16237e-5)
# E(bn) = param(2.79766e-5)
# E(bn) = param(2.86692e-5)
# E(bn) = param(2.63394e-5)
# E(bn) = param(2.41458e-5)
# E(bn) = param(2.36536e-5)
# E(bn) = param(2.20237e-5)
# E(bn) = param(1.71974e-5)
# E(bn) = param(1.56671e-5)
# E(bn) = param(1.62097e-5)
# E(bn) = param(1.44796e-5)
# E(bn) = param(1.14506e-5)
# E(bn) = param(9.66973e-6)
# E(bn) = param(1.14322e-5)
# E(bn) = param(7.50794e-6)
# E(bn) = param(7.21535e-6)
# E(bn) = param(5.68916e-6)
# E(bn) = param(5.39872e-6)
# E(bn) = param(5.02347e-6)
# E(bn) = param(4.24717e-6)
# E(bn) = param(3.51329e-6)
# E(bn) = param(2.17589e-6)
# E(bn) = param(2.503e-6)
# E(bn) = param(1.71808e-6)
# E(bn) = param(1.60288e-6)
# E(bn) = param(1.67539e-6)
# E(bn) = param(1.35108e-6)
# E(bn) = param(7.3913e-7)
# E(bn) = param(6.60762e-7)
# E(bn) = param(7.21923e-7)
# E(bn) = param(4.28722e-7)
# E(bn) = param(3.6098e-7)
# E(bn) = param(1.98486e-7)
# E(bn) = param(2.5439e-7)
# E(bn) = param(1.77923e-7)
# E(bn) = param(1.06133e-7)
# E(bn) = param(9.45749e-8)
# E(bn) = param(1.10605e-7)
# E(bn) = param(9.30162e-8)
# E(bn) = param(7.14298e-8)
# E(bn) = param(5.35462e-8)
# E(bn) = param(1.00265e-7)
# E(bn) = param(6.47862e-8)
# E(bn) = param(5.83606e-8)
# E(bn) = param(5.75018e-8)
# E(bn) = param(5.30496e-8)
# E(bn) = param(4.90551e-8)
# E(bn) = param(6.44856e-8)
# E(bn) = param(6.98799e-8)
# E(bn) = param(6.41626e-8)
# E(bn) = param(7.66183e-8)
# E(bn) = param(6.68417e-8)
# E(bn) = param(7.25984e-8)
# E(bn) = param(7.87651e-8)
# E(bn) = param(5.91594e-8)
# E(bn) = param(6.79351e-8)
# E(bn) = param(6.27762e-8)
# E(bn) = param(5.99782e-8)
# E(bn) = param(6.00118e-8)
# E(bn) = param(5.44003e-8)
# E(bn) = param(5.19576e-8)
# E(bn) = param(4.3664e-8)
# E(bn) = param(4.80783e-8)
# E(bn) = param(4.3654e-8)
# E(bn) = param(4.05888e-8)
# E(bn) = param(4.05101e-8)
# E(bn) = param(3.81768e-8)
# E(bn) = param(2.8884e-8)
# E(bn) = param(2.6618e-8)
# E(bn) = param(2.91141e-8)
# E(bn) = param(2.63812e-8)
# E(bn) = param(2.05575e-8)
# E(bn) = param(1.75865e-8)
# E(bn) = param(2.24677e-8)
# E(bn) = param(1.45337e-8)
# E(bn) = param(1.4192e-8)
# E(bn) = param(1.1775e-8)
# E(bn) = param(1.14234e-8)
# E(bn) = param(1.10705e-8)
# E(bn) = param(9.47314e-9)
# E(bn) = param(8.09735e-9)
# E(bn) = param(5.2293e-9)
# E(bn) = param(6.31165e-9)
# E(bn) = param(4.56901e-9)
# E(bn) = param(4.42319e-9)
# E(bn) = param(4.63313e-9)
# E(bn) = param(3.94425e-9)
# E(bn) = param(2.33667e-9)
# E(bn) = param(2.09025e-9)
# E(bn) = param(2.39029e-9)
# E(bn) = param(1.65251e-9)
# E(bn) = param(1.34232e-9)
# E(bn) = param(8.70367e-10)
# E(bn) = param(1.15317e-9)
# E(bn) = param(7.6112e-10)
# E(bn) = param(5.60391e-10)
# E(bn) = param(4.44387e-10)
# E(bn) = param(4.59919e-10)
# E(bn) = param(4.1354e-10)
# E(bn) = param(3.22039e-10)
# E(bn) = param(2.29461e-10)
# E(bn) = param(1.84967e-10)
# E(bn) = param(1.59629e-10)
# E(bn) = param(7.63232e-11)
# E(bn) = param(8.32603e-11)
# E(bn) = param(8.79229e-11)
# E(bn) = param(5.591e-11)
# E(bn) = param(4.25156e-11)
# E(bn) = param(4.74115e-11)
# E(bn) = param(4.04867e-11)
# E(bn) = param(3.51633e-11)
# E(bn) = param(3.51279e-11)
# E(bn) = param(3.67675e-11)
# E(bn) = param(3.3171e-11)
# E(bn) = param(2.69017e-11)
# E(bn) = param(3.32404e-11)
# E(bn) = param(3.33518e-11)
# E(bn) = param(3.32901e-11)
# E(bn) = param(3.39036e-11)
# E(bn) = param(3.10208e-11)
# E(bn) = param(3.2117e-11)
# E(bn) = param(3.50792e-11)
# E(bn) = param(3.55219e-11)
# E(bn) = param(3.57558e-11)
# E(bn) = param(3.30803e-11)
# E(bn) = param(3.2454e-11)
# E(bn) = param(3.2432e-11)
# E(bn) = param(2.81354e-11)
# E(bn) = param(2.71879e-11)
# E(bn) = param(3.00619e-11)
# E(bn) = param(3.15221e-11)
# E(bn) = param(2.39471e-11)
# E(bn) = param(2.3373e-11)
# E(bn) = param(3.10227e-11)
# E(bn) = param(1.96821e-11)
# E(bn) = param(2.13156e-11)
# E(bn) = param(1.89177e-11)
# E(bn) = param(1.85421e-11)
# E(bn) = param(1.88445e-11)
# E(bn) = param(1.65239e-11)
# E(bn) = param(1.52218e-11)
# E(bn) = param(1.09518e-11)
# E(bn) = param(1.35589e-11)
# E(bn) = param(1.11319e-11)
# E(bn) = param(1.07663e-11)
# E(bn) = param(1.10476e-11)
# E(bn) = param(1.01515e-11)
# E(bn) = param(6.85104e-12)
# E(bn) = param(6.24982e-12)
# E(bn) = param(7.34417e-12)
# E(bn) = param(6.23881e-12)
# E(bn) = param(4.81693e-12)
# E(bn) = param(3.8839e-12)
# E(bn) = param(5.38204e-12)
# E(bn) = param(3.44928e-12)
# E(bn) = param(3.16925e-12)
# E(bn) = param(2.72983e-12)
# E(bn) = param(2.68959e-12)
# E(bn) = param(2.66815e-12)
# E(bn) = param(2.24551e-12)
# E(bn) = param(1.90848e-12)
# E(bn) = param(1.24607e-12)
# E(bn) = param(1.53795e-12)
# E(bn) = param(1.08116e-12)
# E(bn) = param(1.08978e-12)
# E(bn) = param(1.13273e-12)
# E(bn) = param(9.63365e-13)
# E(bn) = param(5.74077e-13)
# E(bn) = param(5.07257e-13)
# E(bn) = param(5.97545e-13)
# E(bn) = param(4.25793e-13)
# E(bn) = param(3.44685e-13)
# E(bn) = param(2.34679e-13)
# E(bn) = param(3.07112e-13)
# E(bn) = param(2.08007e-13)
# E(bn) = param(1.59705e-13)
# E(bn) = param(1.3376e-13)
# E(bn) = param(1.30274e-13)
# E(bn) = param(1.24274e-13)
# E(bn) = param(9.89548e-14)
# E(bn) = param(7.51812e-14)
# E(bn) = param(4.866e-14)
# E(bn) = param(5.23061e-14)
# E(bn) = param(2.806e-14)
# E(bn) = param(3.03563e-14)
# E(bn) = param(3.15045e-14)
# E(bn) = param(2.25648e-14)
# E(bn) = param(1.21809e-14)
# E(bn) = param(1.05098e-14)
# E(bn) = param(1.09415e-14)
# E(bn) = param(5.95498e-15)
# E(bn) = param(5.56591e-15)
# E(bn) = param(3.77031e-15)
# E(bn) = param(2.53672e-15)
# E(bn) = param(2.02778e-15)
# E(bn) = param(1.93168e-15)
# E(bn) = param(1.58182e-15)
